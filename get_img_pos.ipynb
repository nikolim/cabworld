# %% [markdown]
# ## Helper notebook test different cordinates of the world

# %%
import matplotlib.pyplot as plt

img = plt.imread("images/map.png")
fig, ax = plt.subplots(figsize=(15,15))
ax.imshow(img)

ax.scatter(710,230, s=100)
ax.scatter(280,800, s=100)
